# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
data = np.loadtxt('G_S_Ntime.txt',delimiter=',')   
plt.plot(data[:,0],data[:,1])
plt.plot(np.array(list(range(1000))),np.array(list(range(1000)))**3/(2.9e8))
